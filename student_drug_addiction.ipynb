# %%
# import extensive libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
#load dataset using pd
df=pd.read_csv('student_addiction_dataset_test.csv')

# %%
df.head() # top records
# Out:
#   Experimentation Academic_Performance_Decline Social_Isolation  \
# 0             Yes                          Yes              Yes
# 1              No                           No              Yes
# 2              No                           No               No
# 3             Yes                           No              Yes
# 4              No                           No               No
#
#   Financial_Issues Physical_Mental_Health_Problems Legal_Consequences  \
# 0               No                             Yes                 No
# 1               No                              No                Yes
# 2              Yes                              No                Yes
# 3               No                             Yes                Yes
# 4               No                             Yes                 No
#
#   Relationship_Strain Risk_Taking_Behavior Withdrawal_Symptoms  \
# 0                  No                   No                 Yes
# ...

# %%
df.tail() #bottom records
# Out:
#       Experimentation Academic_Performance_Decline Social_Isolation  \
# 12739              No                           No               No
# 12740              No                          Yes              Yes
# 12741              No                           No              Yes
# 12742              No                           No               No
# 12743              No                          Yes               No
#
#       Financial_Issues Physical_Mental_Health_Problems Legal_Consequences  \
# 12739              Yes                              No                 No
# 12740               No                             NaN                 No
# 12741               No                              No                Yes
# 12742               No                              No                Yes
# 12743               No                              No                 No
#
#       Relationship_Strain Risk_Taking_Behavior Withdrawal_Symptoms  \
# ...

# %%
df.columns
# Out:
# Index(['Experimentation', 'Academic_Performance_Decline', 'Social_Isolation',
#        'Financial_Issues', 'Physical_Mental_Health_Problems',
#        'Legal_Consequences', 'Relationship_Strain', 'Risk_Taking_Behavior',
#        'Withdrawal_Symptoms', 'Denial_and_Resistance_to_Treatment',
#        'Addiction_Class'],
#       dtype='object')

# %%
df.describe() # statistical analysis
# Out:
#        Experimentation Academic_Performance_Decline Social_Isolation  \
# count            12099                        12059            12067
# unique               2                            2                2
# top                 No                           No               No
# freq              8412                         8314             8352
#
#        Financial_Issues Physical_Mental_Health_Problems Legal_Consequences  \
# count             12124                           12079              12058
# unique                2                               2                  2
# top                  No                              No                 No
# freq               8392                            8312               8340
#
#        Relationship_Strain Risk_Taking_Behavior Withdrawal_Symptoms  \
# count                12112                12131               12091
# unique                   2                    2                   2
# ...

# %%
df.dtypes # datatypes
# Out:
# Experimentation                       object
# Academic_Performance_Decline          object
# Social_Isolation                      object
# Financial_Issues                      object
# Physical_Mental_Health_Problems       object
# Legal_Consequences                    object
# Relationship_Strain                   object
# Risk_Taking_Behavior                  object
# Withdrawal_Symptoms                   object
# Denial_and_Resistance_to_Treatment    object
# Addiction_Class                       object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12744 entries, 0 to 12743
# Data columns (total 11 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Experimentation                     12099 non-null  object
#  1   Academic_Performance_Decline        12059 non-null  object
#  2   Social_Isolation                    12067 non-null  object
#  3   Financial_Issues                    12124 non-null  object
#  4   Physical_Mental_Health_Problems     12079 non-null  object
#  5   Legal_Consequences                  12058 non-null  object
#  6   Relationship_Strain                 12112 non-null  object
#  7   Risk_Taking_Behavior                12131 non-null  object
#  8   Withdrawal_Symptoms                 12091 non-null  object
#  9   Denial_and_Resistance_to_Treatment  12090 non-null  object
#  10  Addiction_Class                     12744 non-null  object
# dtypes: object(11)
# ...

# %%
df.isnull().sum() # checks missing values
# Out:
# Experimentation                       645
# Academic_Performance_Decline          685
# Social_Isolation                      677
# Financial_Issues                      620
# Physical_Mental_Health_Problems       665
# Legal_Consequences                    686
# Relationship_Strain                   632
# Risk_Taking_Behavior                  613
# Withdrawal_Symptoms                   653
# Denial_and_Resistance_to_Treatment    654
# Addiction_Class                         0
# dtype: int64

# %%
for i in df:
    if df[i].dtype == 'object':
        print(i,df[i].value_counts())
    print('-------------------------') # counting the values present in the column
# Out:
# Experimentation No     8412
# Yes    3687
# Name: Experimentation, dtype: int64
# -------------------------
# Academic_Performance_Decline No     8314
# Yes    3745
# Name: Academic_Performance_Decline, dtype: int64
# -------------------------
# Social_Isolation No     8352
# Yes    3715
# Name: Social_Isolation, dtype: int64
# -------------------------
# Financial_Issues No     8392
# Yes    3732
# Name: Financial_Issues, dtype: int64
# -------------------------
# Physical_Mental_Health_Problems No     8312
# Yes    3767
# Name: Physical_Mental_Health_Problems, dtype: int64
# -------------------------
# Legal_Consequences No     8340
# Yes    3718
# Name: Legal_Consequences, dtype: int64
# -------------------------
# Relationship_Strain No     8334
# Yes    3778
# Name: Relationship_Strain, dtype: int64
# -------------------------
# Risk_Taking_Behavior No     8396
# Yes    3735
# Name: Risk_Taking_Behavior, dtype: int64
# -------------------------
# Withdrawal_Symptoms No     8356
# ...

# %%
df[df.duplicated()]
# Out:
#       Experimentation Academic_Performance_Decline Social_Isolation  \
# 49                 No                           No               No
# 68                Yes                           No               No
# 81                 No                           No               No
# 97                 No                           No               No
# 113               Yes                           No               No
# ...               ...                          ...              ...
# 12738             Yes                           No               No
# 12739              No                           No               No
# 12741              No                           No              Yes
# 12742              No                           No               No
# 12743              No                          Yes               No
#
#       Financial_Issues Physical_Mental_Health_Problems Legal_Consequences  \
# 49                 Yes                              No                 No
# ...

# %%
df.columns
# Out:
# Index(['Experimentation', 'Academic_Performance_Decline', 'Social_Isolation',
#        'Financial_Issues', 'Physical_Mental_Health_Problems',
#        'Legal_Consequences', 'Relationship_Strain', 'Risk_Taking_Behavior',
#        'Withdrawal_Symptoms', 'Denial_and_Resistance_to_Treatment',
#        'Addiction_Class'],
#       dtype='object')

# %%
# missing values are filling with mode

# %%
df['Experimentation']=df["Experimentation"].fillna(df["Experimentation"].mode()[0])

# %%
df['Academic_Performance_Decline']=df["Academic_Performance_Decline"].fillna(df["Academic_Performance_Decline"].mode()[0])

# %%
df['Social_Isolation']=df["Social_Isolation"].fillna(df["Social_Isolation"].mode()[0])

# %%
df['Financial_Issues']=df["Financial_Issues"].fillna(df["Financial_Issues"].mode()[0])

# %%
df['Physical_Mental_Health_Problems']=df["Physical_Mental_Health_Problems"].fillna(df["Physical_Mental_Health_Problems"].mode()[0])

# %%
df['Legal_Consequences']=df["Legal_Consequences"].fillna(df["Legal_Consequences"].mode()[0])

# %%
df['Relationship_Strain']=df["Relationship_Strain"].fillna(df["Relationship_Strain"].mode()[0])

# %%
df['Risk_Taking_Behavior']=df["Risk_Taking_Behavior"].fillna(df["Risk_Taking_Behavior"].mode()[0])

# %%
df['Withdrawal_Symptoms']=df["Withdrawal_Symptoms"].fillna(df["Withdrawal_Symptoms"].mode()[0])

# %%
df['Denial_and_Resistance_to_Treatment']=df["Denial_and_Resistance_to_Treatment"].fillna(df["Denial_and_Resistance_to_Treatment"].mode()[0])

# %%
df['Denial_and_Resistance_to_Treatment']=df["Denial_and_Resistance_to_Treatment"].fillna(df["Denial_and_Resistance_to_Treatment"].mode()[0])

# %%
df.isnull().sum() # fillied missing values
# Out:
# Experimentation                       0
# Academic_Performance_Decline          0
# Social_Isolation                      0
# Financial_Issues                      0
# Physical_Mental_Health_Problems       0
# Legal_Consequences                    0
# Relationship_Strain                   0
# Risk_Taking_Behavior                  0
# Withdrawal_Symptoms                   0
# Denial_and_Resistance_to_Treatment    0
# Addiction_Class                       0
# dtype: int64

# %% [markdown]
# Exploratory Data Analysis

# %%
plt.figure(figsize=(5,5)) # 79.3% are not addicted to drug & 20.7% are addicted
drug_Addiction_Class=df['Addiction_Class'].value_counts()
drug_Addiction_Class.plot(kind='pie',autopct='%1.1f%%')
plt.show()

# %%
sns.countplot(x='Academic_Performance_Decline', hue='Addiction_Class', data=df) 
plt.title('Academic_Performance_Decline & addicted_class')
plt.show()

# %%
sns.countplot(x='Social_Isolation', hue='Addiction_Class', data=df) 
plt.title('Social_Isolation & addicted_class')
plt.show()

# %%
plt.figure(figsize=(5,5)) # 79.3% are not addicted to drug & 20.7% are addicted
drug_Financial_Issues=df['Financial_Issues'].value_counts()
drug_Financial_Issues.plot(kind='pie',autopct='%1.1f%%')
plt.show() # final issuses for students

# %%
sns.countplot(x='Physical_Mental_Health_Problems', hue='Addiction_Class', data=df) 
plt.title('Physical_Mental_Health_Problems & addicted_class')
plt.show()

# %%
df.columns
# Out:
# Index(['Experimentation', 'Academic_Performance_Decline', 'Social_Isolation',
#        'Financial_Issues', 'Physical_Mental_Health_Problems',
#        'Legal_Consequences', 'Relationship_Strain', 'Risk_Taking_Behavior',
#        'Withdrawal_Symptoms', 'Denial_and_Resistance_to_Treatment',
#        'Addiction_Class'],
#       dtype='object')

# %%
sns.countplot(x='Risk_Taking_Behavior', hue='Addiction_Class', data=df) 
plt.title('Risk_Taking_Behavior & addicted_class')
plt.show()

# %%
sns.countplot(x='Denial_and_Resistance_to_Treatment', hue='Addiction_Class', data=df) 
plt.title('Denial_and_Resistance_to_Treatment & addicted_class')
plt.show()

# %%
# encoding
df=pd.get_dummies(df,columns=['Experimentation', 'Academic_Performance_Decline', 'Social_Isolation',
       'Financial_Issues', 'Physical_Mental_Health_Problems',
       'Legal_Consequences', 'Relationship_Strain', 'Risk_Taking_Behavior',
       'Withdrawal_Symptoms', 'Denial_and_Resistance_to_Treatment',
       'Addiction_Class'],drop_first=True)

# %%
df
# Out:
#        Experimentation_Yes  Academic_Performance_Decline_Yes  \
# 0                        1                                 1
# 1                        0                                 0
# 2                        0                                 0
# 3                        1                                 0
# 4                        0                                 0
# ...                    ...                               ...
# 12739                    0                                 0
# 12740                    0                                 1
# 12741                    0                                 0
# 12742                    0                                 0
# 12743                    0                                 1
#
#        Social_Isolation_Yes  Financial_Issues_Yes  \
# 0                         1                     0
# 1                         1                     0
# 2                         0                     1
# ...

# %%
x=df.drop(columns='Addiction_Class_Yes',axis=1)

# %%
y=df['Addiction_Class_Yes']

# %%
x # Addiction_Class_Yes removed from x variable
# Out:
#        Experimentation_Yes  Academic_Performance_Decline_Yes  \
# 0                        1                                 1
# 1                        0                                 0
# 2                        0                                 0
# 3                        1                                 0
# 4                        0                                 0
# ...                    ...                               ...
# 12739                    0                                 0
# 12740                    0                                 1
# 12741                    0                                 0
# 12742                    0                                 0
# 12743                    0                                 1
#
#        Social_Isolation_Yes  Financial_Issues_Yes  \
# 0                         1                     0
# 1                         1                     0
# 2                         0                     1
# ...

# %%
y # Addiction_Class_Yes added y variable
# Out:
# 0        0
# 1        0
# 2        0
# 3        1
# 4        0
#         ..
# 12739    0
# 12740    1
# 12741    1
# 12742    0
# 12743    0
# Name: Addiction_Class_Yes, Length: 12744, dtype: uint8

# %%
# split the dataset for train & test
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train # train value 80%
# Out:
#        Experimentation_Yes  Academic_Performance_Decline_Yes  \
# 4281                     1                                 1
# 3263                     1                                 0
# 7602                     0                                 0
# 2749                     0                                 0
# 6690                     0                                 0
# ...                    ...                               ...
# 4859                     1                                 1
# 3264                     0                                 1
# 9845                     0                                 1
# 10799                    0                                 1
# 2732                     1                                 0
#
#        Social_Isolation_Yes  Financial_Issues_Yes  \
# 4281                      1                     0
# 3263                      0                     1
# 7602                      0                     1
# ...

# %%
y_train # trained values from original dataset 80%
# Out:
# 4281     0
# 3263     1
# 7602     1
# 2749     0
# 6690     0
#         ..
# 4859     1
# 3264     0
# 9845     0
# 10799    0
# 2732     0
# Name: Addiction_Class_Yes, Length: 10195, dtype: uint8

# %%
x_test # test dataset from original
# Out:
#        Experimentation_Yes  Academic_Performance_Decline_Yes  \
# 2252                     0                                 1
# 5806                     1                                 1
# 9471                     1                                 0
# 393                      1                                 0
# 7199                     0                                 1
# ...                    ...                               ...
# 1666                     1                                 1
# 2724                     0                                 0
# 11055                    0                                 0
# 9947                     1                                 0
# 398                      1                                 0
#
#        Social_Isolation_Yes  Financial_Issues_Yes  \
# 2252                      1                     0
# 5806                      0                     0
# 9471                      0                     0
# ...

# %%
y_test # original dataset
# Out:
# 2252     0
# 5806     0
# 9471     0
# 393      0
# 7199     0
#         ..
# 1666     0
# 2724     0
# 11055    1
# 9947     0
# 398      0
# Name: Addiction_Class_Yes, Length: 2549, dtype: uint8

# %%
# patterns into the Data
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=lr.predict(x_test)

# %%
y_pred # predicted by model
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=uint8)

# %%
df['Addiction_Class_Yes'].value_counts()
# Out:
# 0    10105
# 1     2639
# Name: Addiction_Class_Yes, dtype: int64

# %%
from sklearn.metrics import confusion_matrix,f1_score,recall_score,accuracy_score
print(confusion_matrix(y_test,y_pred)) # confusion matrix helps us our model predicts and our decision predicts Tp,Fp,Fn,Tn
# Out:
# [[2008    0]
#  [ 541    0]]

# %%
print(f1_score(y_test,y_pred))
# Out:
# 0.0

# %%
print(recall_score(y_test,y_pred))
# Out:
# 0.0

# %%
# print(accuracy_score(y_test,y_pred))
# Out:
# 0.7877599058454295

# %%
from sklearn.tree import DecisionTreeClassifier
DC=DecisionTreeClassifier()
DC.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=DC.predict(x_test)

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=uint8)

# %%
from sklearn.metrics import confusion_matrix,f1_score,recall_score
print(confusion_matrix(y_test,y_pred))
# Out:
# [[1970   38]
#  [ 532    9]]

# %%
print(f1_score(y_test,y_pred))
# Out:
# 0.030612244897959183

# %%
print(recall_score(y_test,y_pred))
# Out:
# 0.0166358595194085

# %%
from sklearn.ensemble import RandomForestClassifier
Rf=RandomForestClassifier()
Rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred=Rf.predict(x_test)

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=uint8)

# %%
from sklearn.metrics import confusion_matrix,f1_score,recall_score
print(confusion_matrix(y_test,y_pred))
# Out:
# [[1968   40]
#  [ 531   10]]

# %%
print(f1_score(y_test,y_pred))
# Out:
# 0.0338409475465313

# %%
print(recall_score(y_test,y_pred))
# Out:
# 0.018484288354898338

# %%
from xgboost import XGBClassifier
xgb=XGBClassifier()
xgb.fit(x_train,y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
y_pred=xgb.predict(x_test)

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from sklearn.metrics import confusion_matrix,f1_score,recall_score
print(confusion_matrix(y_test,y_pred))
# Out:
# [[1982   26]
#  [ 532    9]]

# %%
print(f1_score(y_test,y_pred))
# Out:
# 0.03125

# %%
print(recall_score(y_test,y_pred))
# Out:
# 0.0166358595194085

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier
from xgboost import XGBClassifier
from sklearn.metrics import f1_score, recall_score
import numpy as np
import matplotlib.pyplot as plt

# Define the models
models = {
    "Logistic Regression": LogisticRegression(max_iter=1000),
    "Decision Tree": DecisionTreeClassifier(),
    "Random Forest": RandomForestClassifier(),
    "XGBoost": XGBClassifier(use_label_encoder=False, eval_metric='logloss')
}

# Initialize lists to store F1 scores and recall scores
f1_scores = []
recalls = []

# Train each model and evaluate
for name, model in models.items():
    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)
    f1_scores.append(f1_score(y_test, y_pred))
    recalls.append(recall_score(y_test, y_pred))

# Plot the results
labels = list(models.keys())
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots(figsize=(10, 6))
rects1 = ax.bar(x - width/2, f1_scores, width, label='F1 Score')
rects2 = ax.bar(x + width/2, recalls, width, label='Recall')

# Add some text for labels, title, and custom x-axis tick labels, etc.
ax.set_ylabel('Scores')
ax.set_title('F1 and Recall Scores by Model')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

# Attach a text label above each bar in rects, displaying its height.
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate(f'{height:.2f}',
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)

fig.tight_layout()
plt.xticks(rotation=45)
plt.show()
